# %% [markdown]
# <a href="https://colab.research.google.com/github/nagarwal1510/Agree-to-Disagree/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# %%
import html5lib
import requests

# %%
url= "https://tosdr.org/en/frontpage"

# %%
df = requests.get(url)

# %%
htmlcontent = df.content
soup= BeautifulSoup(htmlcontent, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://cdn.tosdr.org/themes/crisp/css/bootstrap/bootstrap.min.css?39c53ed6056909d561ee99c5edf6bde6fc5b99346ae4fe52b9b9d0e7b87719a8" rel="stylesheet"/>
# <link href="https://cdn.tosdr.org/themes/crisp/css/sweetalert/sweetalert.min.css?d67e3a716d6014076b000a1ca8f85dfa5836a8c0dd294c040c2490d9acdcbf5e" rel="stylesheet"/>
# <!-- START Default Crisp CSS -->
# <link href="https://cdn.tosdr.org/themes/crisp/css/general.min.css?9b68084858612724b4861de3fc085db8358704701be0981f58993107d3fb7f80" rel="stylesheet"/>
# <link href="https://cdn.tosdr.org/themes/crisp/css/footer.min.css?15d55f74f9fb6a9ba27d2abadd553e22260d70324d1176bcf37eefa5c2c83588" rel="stylesheet"/>
# <link href="https://cdn.tosdr.org/themes/crisp/css/ribbon.min.css?98054f7436ec5d412f3a167b922ee4b14591d3a8486072a07303d9d5334f5f49" rel="stylesheet"/>
# ...

# %%
soup_p=soup.prettify()

# %%
print(soup.title)
print(soup.title.name)
print(soup.title.string)
print(soup.parent)
print(soup.p)
print(soup.a.prettify())
# Out:
# <title>Frontpage -- Terms of Service; Didn't Read</title>
# title
# Frontpage -- Terms of Service; Didn't Read
# None
# <p>We are a user rights <a href="/about" title="Learn more about us">initiative</a> to <a href="/classification" title="What's our classification?">rate and label</a> website terms &amp; privacy policies, from very good <span class="label A">Class A</span> to very bad <span class="label E">Class E</span>.</p>
# <a class="navbar-brand" href="/">
#  <img alt="Logo" src="https://s3.tosdr.org/branding/tosdr-icon-32.svg" width="32"/>
# </a>

# %%
print(soup.find_all('a'))
# Out:
# [<a class="navbar-brand" href="/"><img alt="Logo" src="https://s3.tosdr.org/branding/tosdr-icon-32.svg" width="32"/></a>, <a class="nav-link active" href="/en/frontpage" target="_self">Home</a>, <a class="nav-link " href="/en/frontpage#ratings" target="_self">Ratings</a>, <a class="nav-link " href="/en/about" target="_self">About Us</a>, <a class="nav-link " href="/en/downloads" target="_self">Download Extensions</a>, <a class="nav-link " href="/en/api" target="_self">API</a>, <a class="nav-link " href="https://forum.tosdr.org" target="_self">Forum</a>, <a class="nav-link " href="https://status.tosdr.org" target="_self">Status Page</a>, <a class="nav-link " href="/login" target="_self">Login</a>, <a class="nav-link " href="/en/new_service" target="_self">Add a new Service</a>, <a class="nav-link " href="/en/community" target="_self">Communities</a>, <a class="nav-link " href="/en/donate" target="_self">Donate</a>, <a href="/?universe=2"><span class="badge badge-warning"><i class="fas
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /en/frontpage
# /en/frontpage#ratings
# /en/about
# /en/downloads
# /en/api
# https://forum.tosdr.org
# https://status.tosdr.org
# /login
# /en/new_service
# /en/community
# /en/donate
# /?universe=2
# #
# /en/frontpage
# /de/frontpage
# /es/frontpage
# /es_MX/frontpage
# /fr/frontpage
# /nl/frontpage
# /pl/frontpage
# /pt_BR/frontpage
# /ru/frontpage
# /about
# /classification
# #ratings
# /en/downloads
# https://edit.tosdr.org
# https://moneyland.time.com/2012/08/10/new-site-grades-those-pesky-terms-of-service-agreements-you-never-read/
# https://gigaom.com/2012/08/14/i-agree-why-terms-of-service-report-cards-are-a-good-idea/
# https://www.theverge.com/2012/8/14/3241572/tos-dr-terms-of-service
# https://www.lemonde.fr/technologies/article/2012/08/14/un-site-veut-mettre-fin-au-mensonge-des-conditions-d-utilisation-sur-internet_1745942_651865.html
# https://www.zeit.de/digital/internet/2012-08/terms-of-service-did-not-read
# ...

# %%
print(soup.get_text())
# Out:
# Frontpage -- Terms of Service; Didn't Read
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Ratings
#
#
# About Us
#
#
# Download Extensions
#
#
# API
#
#
# Forum
#
#
# Status Page
#
#
# Login
#
#
# Add a new Service
#
#
# Communities
#
#
#
#
# Donate
#
#
#  JOIN BETA
#
#
#
#
#  English
#
#
#
#
#                                 English
#
#
#
#
#                                 Deutsch
#
#                                         (German)
#
#
#
#
#
#                                 Español
#
#                                         (Spanish)
#
#
#
#
#
#                                 Español mexicano
#
#                                         (Mexican Spanish)
#
#
#
#
#
#                                 Français
#
#                                         (French)
#
#
#
#
#
#                                 Nederlands
#
#                                         (Dutch)
#
#
#
#
#
#                                 Polski
#
#                                         (Polish)
#
#
#
#
#
# ...

# %%
soup.a
# Out:
# <a class="navbar-brand" href="/"><img alt="Logo" src="https://s3.tosdr.org/branding/tosdr-icon-32.svg" width="32"/></a>

# %%
soup.attrs
# Out:
# {}
